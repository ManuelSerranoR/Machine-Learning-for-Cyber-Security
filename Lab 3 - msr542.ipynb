# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
learning_rate_AM = 0.001
training_epochs = 10
batch_size = 100
display_step = 1
save_images = False

# tf Graph Input
x = tf.placeholder(tf.float32, [None, 784]) # mnist data image of shape 28*28=784
x_for_RMSE = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10]) # 0-9 digits recognition => 10 classes
W1_laplacian = tf.placeholder(tf.float32, [784, 300])
W3_laplacian = tf.placeholder(tf.float32, [300, 10])

# Set model weights
W1 = tf.Variable(tf.random_normal([784, 300], mean=0, stddev=1))
b1 = tf.Variable(tf.random_normal([300], mean=0, stddev = 1))

#W2 = tf.Variable(tf.random_normal([300, 100], mean=0, stddev= 1))
#b2 = tf.Variable(tf.random_normal([100], mean=0, stddev= 1))

W3 = tf.Variable(tf.zeros([300, 10]))
b3 = tf.Variable(tf.zeros([10]))

# Construct model
def dnn(x):
    hidden1 = tf.nn.relu(tf.matmul(x, W1) + b1); #first hidden layer
    #hidden2 = tf.nn.relu(tf.matmul(hidden1, W2) + b2); #second hidden layer
    pred = tf.nn.softmax(tf.matmul(hidden1, W3) + b3) # Softmax layer outputs prediction probabilities
    return pred

updateW1 = W1.assign(tf.add(W1, W1_laplacian))
updateW3 = W3.assign(tf.add(W3, W3_laplacian))
    
'''
# Construct model LaPlacian
def dnn_laplacian(x):
    hidden1_laplacian = tf.nn.relu(tf.matmul(x, W1+W1_laplacian) + b1); #first hidden layer
    #hidden2 = tf.nn.relu(tf.matmul(hidden1, W2) + b2); #second hidden layer
    pred_laplacian = tf.nn.softmax(tf.matmul(hidden1_laplacian, W3+W1_laplacian) + b3) # Softmax layer outputs prediction probabilities
    return pred_laplacian
'''

def AM(x, y, learning_rate=learning_rate_AM):
    pred = dnn(x)
    cost = tf.reduce_mean(-tf.reduce_sum(y*tf.log(pred), reduction_indices=1))
    gra, = tf.gradients(cost, x)
    gra = tf.stop_gradient(gra)
    adv_x = x - (learning_rate * gra)
    adv_x = tf.clip_by_value(adv_x, 0.0, 1.0)
    return adv_x
    
# Model output
pred = dnn(x)

# Minimize error using cross entropy 
cost = tf.reduce_mean(-tf.reduce_sum(y*tf.log(pred), reduction_indices=1))
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Metrics
correct_prediction = tf.equal(tf.argmax(pred, axis=1), tf.argmax(y, axis=1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
prob_pred_y = tf.reduce_max(pred)
RMSE = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(x, x_for_RMSE)), axis=1))
min_RMSE = tf.reduce_min(RMSE)

# %%
# Start training
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Fit training using batch data
            _, c = sess.run([optimizer, cost], feed_dict={x: batch_xs, y: batch_ys})
            # Compute average loss
            avg_cost += c / total_batch
            
        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            print ("Epoch:", '%02d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost))

    print ("Optimization Finished! \n")
    
    # Test model with original examples
    print ("Accuracy on original test samples:", sess.run(accuracy, {x: mnist.test.images, y: mnist.test.labels}))
    
    
    ### Activation maximization
    AM_image = AM(x, y)
    break_probability = 0.0001
    numbers = np.zeros((10,10))
    for i in range(10): numbers[i,i]=1
        
    # Step 1: Image randomly initialized
    print("Step 1: Image randomly initialized")
    store_RMSE_random = []
    for digit in range(10):
        image = np.random.rand(1,784)
        prob_old, prob_new = 0, 1
        for i in range(100000):
            image = sess.run(AM_image, {x: image, y: [numbers[digit]]})
            if i%1000 == 0:
                prob_old = prob_new
                prob_new = sess.run(prob_pred_y, {x: image, y: [numbers[digit]]})
                print("Prediction probability:", prob_new)
                if (abs(prob_old-prob_new)<break_probability): 
                    print("No change in probability, breaking the loop")
                    print("Calculating minimum RMSE of image computed against all train samples:")
                    calc_RMSE = sess.run(min_RMSE, {x: mnist.train.images, x_for_RMSE: image})
                    store_RMSE_random.append(calc_RMSE)
                    print('RMSE of digit', digit, "is", calc_RMSE)
                    print("Saving image of digit", digit)
                    plt.imsave('images/random/randomInit_'+str(digit)+'.png', image.reshape(28, 28))
                    break
    print("Final RMSE is", np.mean(np.array(store_RMSE_random)))
                    
    # Step 2: Image initialized from train dataset mean
    print("Step 2: Image initialized from train dataset mean")
    store_RMSE_mean = []
    image_mean_truth = [np.mean(mnist.train.images, axis=0)]
    for digit in range(10):
        image_mean = image_mean_truth
        prob_old, prob_new = 0, 1
        for i in range(100000):
            image_mean = sess.run(AM_image, {x: image_mean, y: [numbers[digit]]})
            if i%1000 == 0:
                prob_old = prob_new
                prob_new = sess.run(prob_pred_y, {x: image_mean, y: [numbers[digit]]})
                print("Prediction probability:", prob_new)
                if (abs(prob_old-prob_new)<break_probability): 
                    print("No change in probability, breaking the loop")
                    print("Calculating minimum RMSE of image computed against all train samples:")
                    calc_RMSE = sess.run(min_RMSE, {x: mnist.train.images, x_for_RMSE: image_mean})
                    store_RMSE_mean.append(calc_RMSE)
                    print('RMSE of digit', digit, "is", calc_RMSE)
                    print("Saving image of digit", digit)
                    plt.imsave('images/mean/meanInit_'+str(digit)+'.png', image_mean.reshape(28, 28))
                    break
    print("Final RMSE is", np.mean(np.array(store_RMSE_mean)))

    # Step 3: Image initialized from train dataset mean for each class
    print("Step 3: Image initialized from train dataset mean for each class")
    store_RMSE_mean_class = []
    for digit in range(10):
        indexes = np.where(np.where(mnist.train.labels == 1)[1] == digit) #Indexes of desired digit in training dataset
        image_mean_class = [np.mean(mnist.train.images[indexes], axis=0)]
        prob_old, prob_new = 0, 1
        for i in range(100000):
            image_mean_class = sess.run(AM_image, {x: image_mean_class, y: [numbers[digit]]})
            if i%1000 == 0:
                prob_old = prob_new
                prob_new = sess.run(prob_pred_y, {x: image_mean_class, y: [numbers[digit]]})
                print("Prediction probability:", prob_new)
                if (abs(prob_old-prob_new)<break_probability): 
                    print("No change in probability, breaking the loop")
                    print("Calculating minimum RMSE of image computed against all train samples:")
                    calc_RMSE = sess.run(min_RMSE, {x: mnist.train.images, x_for_RMSE: image_mean_class})
                    store_RMSE_mean_class.append(calc_RMSE)
                    print('RMSE of digit', digit, "is", calc_RMSE)
                    print("Saving image of digit", digit)
                    plt.imsave('images/mean_class/meanClassInit_'+str(digit)+'.png', image_mean_class.reshape(28, 28))
                    break
    print("Final RMSE is", np.mean(np.array(store_RMSE_mean_class)))
# Out:
# Epoch: 01 cost= 0.572865174
# Epoch: 02 cost= 0.371025438
# Epoch: 03 cost= 0.334366951
# Epoch: 04 cost= 0.314203779
# Epoch: 05 cost= 0.300350308
# Epoch: 06 cost= 0.290548672
# Epoch: 07 cost= 0.282572925
# Epoch: 08 cost= 0.275964022
# Epoch: 09 cost= 0.270828644
# Epoch: 10 cost= 0.266577676
# Optimization Finished!
#
# Accuracy on original test samples: 0.9245
# Step 1: Image randomly initialized
# Prediction probability: 0.98963773
# Prediction probability: 0.9881919
# Prediction probability: 0.99425197
# Prediction probability: 0.9961845
# Prediction probability: 0.99713194
# Prediction probability: 0.99769574
# Prediction probability: 0.9980751
# Prediction probability: 0.99834585
# Prediction probability: 0.998548
# Prediction probability: 0.99870574
# Prediction probability: 0.99883145
# Prediction probability: 0.998933
# Prediction probability: 0.99901795
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 0 is 0.5299318
# Saving image of digit 0
# Prediction probability: 0.9451039
# Prediction probability: 0.97138065
# Prediction probability: 0.9877438
# Prediction probability: 0.9921474
# Prediction probability: 0.994201
# Prediction probability: 0.995391
# Prediction probability: 0.9961718
# Prediction probability: 0.9967229
# Prediction probability: 0.99713457
# Prediction probability: 0.99745387
# Prediction probability: 0.9977088
# Prediction probability: 0.9979169
# Prediction probability: 0.9980902
# Prediction probability: 0.99823654
# Prediction probability: 0.99836224
# Prediction probability: 0.99847084
# Prediction probability: 0.99856585
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 1 is 0.5396509
# Saving image of digit 1
# Prediction probability: 0.7842671
# Prediction probability: 0.986152
# Prediction probability: 0.99303997
# Prediction probability: 0.9953263
# Prediction probability: 0.99647045
# Prediction probability: 0.9971631
# Prediction probability: 0.9976284
# Prediction probability: 0.997962
# Prediction probability: 0.99821293
# Prediction probability: 0.9984086
# Prediction probability: 0.99856573
# Prediction probability: 0.99869424
# Prediction probability: 0.99880147
# Prediction probability: 0.9988925
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 2 is 0.5339292
# Saving image of digit 2
# Prediction probability: 0.9887651
# Prediction probability: 0.98760605
# Prediction probability: 0.993551
# Prediction probability: 0.99557483
# Prediction probability: 0.9966107
# Prediction probability: 0.99724317
# Prediction probability: 0.99765754
# Prediction probability: 0.9979558
# Prediction probability: 0.99818534
# Prediction probability: 0.9983677
# Prediction probability: 0.99851626
# Prediction probability: 0.9986393
# Prediction probability: 0.9987435
# Prediction probability: 0.9988324
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 3 is 0.54257715
# Saving image of digit 3
# Prediction probability: 0.55928695
# Prediction probability: 0.9782089
# Prediction probability: 0.99003905
# Prediction probability: 0.99351984
# Prediction probability: 0.9951782
# Prediction probability: 0.99616003
# Prediction probability: 0.9967989
# Prediction probability: 0.9972549
# Prediction probability: 0.9975926
# Prediction probability: 0.9978557
# Prediction probability: 0.9980667
# Prediction probability: 0.99824
# Prediction probability: 0.9983846
# Prediction probability: 0.9985072
# Prediction probability: 0.9986125
# Prediction probability: 0.9987024
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 4 is 0.5319937
# Saving image of digit 4
# Prediction probability: 0.4949658
# Prediction probability: 0.98879516
# Prediction probability: 0.9942842
# Prediction probability: 0.99612194
# Prediction probability: 0.9970548
# Prediction probability: 0.99762243
# Prediction probability: 0.99800485
# Prediction probability: 0.9982809
# Prediction probability: 0.99848855
# Prediction probability: 0.9986511
# Prediction probability: 0.9987816
# Prediction probability: 0.9988889
# Prediction probability: 0.99897873
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 5 is 0.53256905
# Saving image of digit 5
# Prediction probability: 0.4869802
# Prediction probability: 0.98452735
# Prediction probability: 0.9924092
# Prediction probability: 0.9949654
# Prediction probability: 0.9962314
# Prediction probability: 0.99698704
# Prediction probability: 0.99748623
# Prediction probability: 0.9978423
# Prediction probability: 0.9981091
# Prediction probability: 0.998317
# Prediction probability: 0.9984837
# Prediction probability: 0.9986198
# Prediction probability: 0.9987336
# Prediction probability: 0.99882954
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 6 is 0.5313038
# Saving image of digit 6
# Prediction probability: 0.5041907
# Prediction probability: 0.98480415
# Prediction probability: 0.99268883
# Prediction probability: 0.9951617
# Prediction probability: 0.9963587
# Prediction probability: 0.9970778
# Prediction probability: 0.9975581
# Prediction probability: 0.9979023
# Prediction probability: 0.998161
# Prediction probability: 0.9983627
# Prediction probability: 0.9985245
# Prediction probability: 0.99865687
# Prediction probability: 0.9987674
# Prediction probability: 0.9988612
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 7 is 0.53378767
# Saving image of digit 7
# Prediction probability: 0.96518046
# Prediction probability: 0.98666173
# Prediction probability: 0.993252
# Prediction probability: 0.9954503
# Prediction probability: 0.9965592
# Prediction probability: 0.9972256
# Prediction probability: 0.9976707
# Prediction probability: 0.9979911
# Prediction probability: 0.99823296
# Prediction probability: 0.9984219
# Prediction probability: 0.99857366
# Prediction probability: 0.99869835
# Prediction probability: 0.99880266
# Prediction probability: 0.9988913
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 8 is 0.52833927
# Saving image of digit 8
# Prediction probability: 0.56622887
# Prediction probability: 0.9858233
# Prediction probability: 0.99261624
# Prediction probability: 0.99491286
# Prediction probability: 0.9961034
# Prediction probability: 0.99683577
# Prediction probability: 0.99733293
# Prediction probability: 0.997693
# Prediction probability: 0.9979633
# Prediction probability: 0.99817467
# Prediction probability: 0.9983456
# Prediction probability: 0.9984865
# Prediction probability: 0.9986045
# Prediction probability: 0.9987048
# Prediction probability: 0.9987907
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 9 is 0.541958
# Saving image of digit 9
# Final RMSE is 0.5346041
# Step 2: Image initialized from train dataset mean
# Prediction probability: 0.77197
# Prediction probability: 0.979159
# Prediction probability: 0.98958975
# Prediction probability: 0.9928929
# Prediction probability: 0.9945227
# Prediction probability: 0.99553645
# Prediction probability: 0.9962297
# Prediction probability: 0.9967344
# Prediction probability: 0.9971174
# Prediction probability: 0.9974165
# Prediction probability: 0.9976587
# Prediction probability: 0.9978588
# Prediction probability: 0.9980268
# Prediction probability: 0.9981698
# Prediction probability: 0.9982951
# Prediction probability: 0.99840456
# Prediction probability: 0.9985024
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 0 is 0.19367473
# Saving image of digit 0
# Prediction probability: 0.7724755
# Prediction probability: 0.9627325
# Prediction probability: 0.98212564
# Prediction probability: 0.98810834
# Prediction probability: 0.9910884
# Prediction probability: 0.99289316
# Prediction probability: 0.99408084
# Prediction probability: 0.99492174
# Prediction probability: 0.9955527
# Prediction probability: 0.99604416
# Prediction probability: 0.996436
# Prediction probability: 0.99675673
# Prediction probability: 0.99702543
# Prediction probability: 0.99725264
# Prediction probability: 0.9974475
# Prediction probability: 0.9976164
# Prediction probability: 0.99776435
# Prediction probability: 0.997895
# Prediction probability: 0.99801105
# Prediction probability: 0.99811494
# Prediction probability: 0.9982083
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 1 is 0.19567272
# Saving image of digit 1
# Prediction probability: 0.77207744
# Prediction probability: 0.9826622
# Prediction probability: 0.9911874
# Prediction probability: 0.9940631
# Prediction probability: 0.99550396
# Prediction probability: 0.9963678
# Prediction probability: 0.99694985
# Prediction probability: 0.99737024
# Prediction probability: 0.99768794
# Prediction probability: 0.99793446
# Prediction probability: 0.99813277
# Prediction probability: 0.99829584
# Prediction probability: 0.9984327
# Prediction probability: 0.99854904
# Prediction probability: 0.9986493
# Prediction probability: 0.9987363
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 2 is 0.19227889
# Saving image of digit 2
# Prediction probability: 0.76950336
# Prediction probability: 0.9812077
# Prediction probability: 0.9902928
# Prediction probability: 0.9933316
# Prediction probability: 0.99489826
# Prediction probability: 0.9958609
# Prediction probability: 0.99651307
# Prediction probability: 0.99698097
# Prediction probability: 0.9973328
# Prediction probability: 0.99761
# Prediction probability: 0.99783415
# Prediction probability: 0.9980192
# Prediction probability: 0.9981749
# Prediction probability: 0.9983071
# Prediction probability: 0.99842155
# Prediction probability: 0.99852115
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 3 is 0.19389032
# Saving image of digit 3
# Prediction probability: 0.77067727
# Prediction probability: 0.98127306
# Prediction probability: 0.9907452
# Prediction probability: 0.9938361
# Prediction probability: 0.99537563
# Prediction probability: 0.9962968
# Prediction probability: 0.9969023
# Prediction probability: 0.997334
# Prediction probability: 0.9976599
# Prediction probability: 0.9979134
# Prediction probability: 0.9981158
# Prediction probability: 0.9982811
# Prediction probability: 0.99841905
# Prediction probability: 0.99853647
# Prediction probability: 0.9986376
# Prediction probability: 0.99872607
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 4 is 0.19172852
# Saving image of digit 4
# Prediction probability: 0.77395785
# Prediction probability: 0.9802443
# Prediction probability: 0.99043626
# Prediction probability: 0.9936187
# Prediction probability: 0.99524766
# Prediction probability: 0.99620545
# Prediction probability: 0.9968252
# Prediction probability: 0.9972621
# Prediction probability: 0.99759275
# Prediction probability: 0.9978515
# Prediction probability: 0.99805945
# Prediction probability: 0.99823064
# Prediction probability: 0.99837375
# Prediction probability: 0.9984945
# Prediction probability: 0.99859816
# Prediction probability: 0.99868864
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 5 is 0.19298899
# Saving image of digit 5
# Prediction probability: 0.7728961
# Prediction probability: 0.9803084
# Prediction probability: 0.99024147
# Prediction probability: 0.9934651
# Prediction probability: 0.99505
# Prediction probability: 0.9960129
# Prediction probability: 0.996648
# Prediction probability: 0.99709046
# Prediction probability: 0.9974291
# Prediction probability: 0.99769634
# Prediction probability: 0.9979132
# Prediction probability: 0.9980925
# Prediction probability: 0.99824286
# Prediction probability: 0.9983708
# Prediction probability: 0.99848443
# Prediction probability: 0.99858296
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 6 is 0.19117503
# Saving image of digit 6
# Prediction probability: 0.7681973
# Prediction probability: 0.9789226
# Prediction probability: 0.9897455
# Prediction probability: 0.9932234
# Prediction probability: 0.9949421
# Prediction probability: 0.9959424
# Prediction probability: 0.9966009
# Prediction probability: 0.9970714
# Prediction probability: 0.9974232
# Prediction probability: 0.99769396
# Prediction probability: 0.9979134
# Prediction probability: 0.9980946
# Prediction probability: 0.99824667
# Prediction probability: 0.99837625
# Prediction probability: 0.99848783
# Prediction probability: 0.9985852
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 7 is 0.19196415
# Saving image of digit 7
# Prediction probability: 0.78041345
# Prediction probability: 0.97614825
# Prediction probability: 0.98683053
# Prediction probability: 0.99081635
# Prediction probability: 0.99290836
# Prediction probability: 0.9942239
# Prediction probability: 0.99512637
# Prediction probability: 0.99578387
# Prediction probability: 0.99627554
# Prediction probability: 0.9966624
# Prediction probability: 0.9969747
# Prediction probability: 0.9972324
# Prediction probability: 0.99744934
# Prediction probability: 0.9976342
# Prediction probability: 0.9977933
# Prediction probability: 0.9979323
# Prediction probability: 0.9980533
# Prediction probability: 0.9981591
# Prediction probability: 0.9982541
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 8 is 0.19231872
# Saving image of digit 8
# Prediction probability: 0.7712932
# Prediction probability: 0.9736154
# Prediction probability: 0.9860178
# Prediction probability: 0.9903831
# Prediction probability: 0.9925539
# Prediction probability: 0.9938547
# Prediction probability: 0.9947556
# Prediction probability: 0.9954326
# Prediction probability: 0.99595165
# Prediction probability: 0.9963619
# Prediction probability: 0.99669087
# Prediction probability: 0.9969638
# Prediction probability: 0.99719477
# Prediction probability: 0.9973929
# Prediction probability: 0.9975637
# Prediction probability: 0.99771285
# Prediction probability: 0.9978441
# Prediction probability: 0.9979607
# Prediction probability: 0.9980634
# Prediction probability: 0.998156
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 9 is 0.19079451
# Saving image of digit 9
# Final RMSE is 0.19264865
# Step 3: Image initialized from train dataset mean for each class
# Prediction probability: 0.99900395
# Prediction probability: 0.99907255
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 0 is 0.18042178
# Saving image of digit 0
# Prediction probability: 0.9614359
# Prediction probability: 0.9880768
# Prediction probability: 0.9925728
# Prediction probability: 0.9945386
# Prediction probability: 0.9956612
# Prediction probability: 0.99638796
# Prediction probability: 0.99689746
# Prediction probability: 0.9972766
# Prediction probability: 0.99756646
# Prediction probability: 0.9977958
# Prediction probability: 0.9979836
# Prediction probability: 0.99813914
# Prediction probability: 0.99827147
# Prediction probability: 0.99838567
# Prediction probability: 0.99848515
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 1 is 0.11106408
# Saving image of digit 1
# Prediction probability: 0.9817015
# Prediction probability: 0.9923884
# Prediction probability: 0.9950165
# Prediction probability: 0.9962586
# Prediction probability: 0.9969971
# Prediction probability: 0.9974873
# Prediction probability: 0.99783605
# Prediction probability: 0.9980951
# Prediction probability: 0.9982932
# Prediction probability: 0.99845135
# Prediction probability: 0.9985825
# Prediction probability: 0.9986926
# Prediction probability: 0.9987864
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 2 is 0.19256178
# Saving image of digit 2
# Prediction probability: 0.9708576
# Prediction probability: 0.9921199
# Prediction probability: 0.99533975
# Prediction probability: 0.9966671
# Prediction probability: 0.9973917
# Prediction probability: 0.99785244
# Prediction probability: 0.9981719
# Prediction probability: 0.9984066
# Prediction probability: 0.9985856
# Prediction probability: 0.99872583
# Prediction probability: 0.9988393
# Prediction probability: 0.998933
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 3 is 0.1691014
# Saving image of digit 3
# Prediction probability: 0.96098995
# Prediction probability: 0.9906577
# Prediction probability: 0.9945147
# Prediction probability: 0.9960859
# Prediction probability: 0.99693537
# Prediction probability: 0.9974655
# Prediction probability: 0.99783427
# Prediction probability: 0.9981054
# Prediction probability: 0.9983139
# Prediction probability: 0.9984799
# Prediction probability: 0.99861526
# Prediction probability: 0.9987274
# Prediction probability: 0.99882215
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 4 is 0.16408665
# Saving image of digit 4
# Prediction probability: 0.7299409
# Prediction probability: 0.9858305
# Prediction probability: 0.9925702
# Prediction probability: 0.99492633
# Prediction probability: 0.99612844
# Prediction probability: 0.9968657
# Prediction probability: 0.99736196
# Prediction probability: 0.9977175
# Prediction probability: 0.9979867
# Prediction probability: 0.9981987
# Prediction probability: 0.9983701
# Prediction probability: 0.9985115
# Prediction probability: 0.99863005
# Prediction probability: 0.9987307
# Prediction probability: 0.9988175
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 5 is 0.18561293
# Saving image of digit 5
# Prediction probability: 0.9914882
# Prediction probability: 0.99475914
# Prediction probability: 0.99616724
# Prediction probability: 0.9969562
# Prediction probability: 0.9974584
# Prediction probability: 0.99781525
# Prediction probability: 0.99807215
# Prediction probability: 0.9982693
# Prediction probability: 0.9984285
# Prediction probability: 0.9985599
# Prediction probability: 0.9986701
# Prediction probability: 0.9987639
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 6 is 0.17055137
# Saving image of digit 6
# Prediction probability: 0.9442795
# Prediction probability: 0.9890597
# Prediction probability: 0.9938844
# Prediction probability: 0.9957183
# Prediction probability: 0.99668497
# Prediction probability: 0.9972874
# Prediction probability: 0.9977023
# Prediction probability: 0.99800485
# Prediction probability: 0.9982389
# Prediction probability: 0.99842477
# Prediction probability: 0.9985745
# Prediction probability: 0.99869823
# Prediction probability: 0.99880207
# Prediction probability: 0.99889046
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 7 is 0.14990795
# Saving image of digit 7
# Prediction probability: 0.99297863
# Prediction probability: 0.99487597
# Prediction probability: 0.9959186
# Prediction probability: 0.9965917
# Prediction probability: 0.997065
# Prediction probability: 0.99741554
# Prediction probability: 0.99768555
# Prediction probability: 0.99790275
# Prediction probability: 0.99808145
# Prediction probability: 0.9982309
# Prediction probability: 0.9983581
# Prediction probability: 0.9984668
# Prediction probability: 0.99855953
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 8 is 0.17295365
# Saving image of digit 8
# Prediction probability: 0.96860486
# Prediction probability: 0.98710364
# Prediction probability: 0.99153805
# Prediction probability: 0.99364144
# Prediction probability: 0.99489367
# Prediction probability: 0.9957287
# Prediction probability: 0.9963121
# Prediction probability: 0.9967384
# Prediction probability: 0.9970734
# Prediction probability: 0.99734265
# Prediction probability: 0.9975661
# Prediction probability: 0.9977533
# Prediction probability: 0.9979128
# Prediction probability: 0.9980501
# Prediction probability: 0.9981699
# Prediction probability: 0.9982753
# Prediction probability: 0.9983657
# No change in probability, breaking the loop
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 9 is 0.16385044
# Saving image of digit 9
# Final RMSE is 0.16601118

# %%
### Section 4
training_epochs1 = 20
with tf.Session() as sess1:
    sess1.run(tf.global_variables_initializer())    
    # Training cycle
    for epoch in range(training_epochs1):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Fit training using batch data
            _, c = sess1.run([optimizer, cost], feed_dict={x: batch_xs, y: batch_ys})
            # Compute average loss
            avg_cost += c / total_batch
            
        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            print ("Epoch:", '%02d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost))

    print ("Optimization Finished! \n")
    
    # Test model with original examples
    print ("Accuracy on original test samples and untouched weights:", sess1.run(accuracy, {x: mnist.test.images, y: mnist.test.labels}))
    
    flatten_W1_W3 = np.concatenate((sess1.run(W1).flatten(),sess1.run(W3).flatten()))
    std = np.std(flatten_W1_W3)
    a = np.array([0.01,0.1,0.5,1])
    #I calculated std above, and realized that is always very near 1. For simplicity, we will approximate std to 1 to
    #keep the lambdas
    std=1
    lambdas = a*std
    AM_image = AM(x, y)
    for l in lambdas:
        lapNoise1 = np.random.laplace(scale=l, size=[784, 300])
        lapNoise3 = np.random.laplace(scale=l, size=[300, 10])
        sess1.run(updateW1, feed_dict={W1_laplacian: lapNoise1})
        sess1.run(updateW3, feed_dict={W3_laplacian: lapNoise3})
        print("Accuracy on test images using DP with lambda", l, "is", sess1.run(accuracy, {x: mnist.test.images, y: mnist.test.labels}))
        
        #Now we perform AM
        store_RMSE_mean_class_differential_privacy = []
        for digit in range(10):
            indexes = np.where(np.where(mnist.train.labels == 1)[1] == digit) #Indexes of desired digit in training dataset
            image_mean_class = [np.mean(mnist.train.images[indexes], axis=0)]
            prob_old, prob_new = 0, 1
            for i in range(10000):
                image_mean_class = sess1.run(AM_image, {x: image_mean_class, y: [numbers[digit]]})
                if i == 10000-1:
                    print("Calculating minimum RMSE of image computed against all train samples:")
                    calc_RMSE = sess1.run(min_RMSE, {x: mnist.train.images, x_for_RMSE: image_mean_class})
                    store_RMSE_mean_class_differential_privacy.append(calc_RMSE)
                    print('RMSE of digit', digit, "is", calc_RMSE)
                    print("Saving image of digit", digit)
                    plt.imsave('images/DP_images/meanClassInitDP_lambda'+str(l)+"digit"+str(digit)+'.png', image_mean_class.reshape(28, 28))
                    
        print("Final RMSE is", np.mean(np.array(store_RMSE_mean_class_differential_privacy)))
# Out:
# Epoch: 01 cost= 0.564991195
# Epoch: 02 cost= 0.365994075
# Epoch: 03 cost= 0.330414759
# Epoch: 04 cost= 0.310330007
# Epoch: 05 cost= 0.297360740
# Epoch: 06 cost= 0.287524693
# Epoch: 07 cost= 0.280095532
# Epoch: 08 cost= 0.274021722
# Epoch: 09 cost= 0.268250526
# Epoch: 10 cost= 0.264081924
# Epoch: 11 cost= 0.259888196
# Epoch: 12 cost= 0.257097375
# Epoch: 13 cost= 0.253903738
# Epoch: 14 cost= 0.251242252
# Epoch: 15 cost= 0.248310407
# Epoch: 16 cost= 0.246600948
# Epoch: 17 cost= 0.244113633
# Epoch: 18 cost= 0.242392528
# Epoch: 19 cost= 0.240654330
# Epoch: 20 cost= 0.239079048
# Optimization Finished!
#
# Accuracy on original test samples and untouched weights: 0.926
# Accuracy on test images using DP with lambda 0.01 is 0.8708
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 0 is 0.1803478
# Saving image of digit 0
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 1 is 0.11118211
# Saving image of digit 1
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 2 is 0.19211414
# Saving image of digit 2
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 3 is 0.16892228
# Saving image of digit 3
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 4 is 0.1643541
# Saving image of digit 4
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 5 is 0.18472287
# Saving image of digit 5
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 6 is 0.17021745
# Saving image of digit 6
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 7 is 0.14986904
# Saving image of digit 7
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 8 is 0.17335342
# Saving image of digit 8
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 9 is 0.16307996
# Saving image of digit 9
# Final RMSE is 0.16581632
# Accuracy on test images using DP with lambda 0.1 is 0.2463
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 0 is 0.18006684
# Saving image of digit 0
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 1 is 0.11221722
# Saving image of digit 1
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 2 is 0.1928854
# Saving image of digit 2
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 3 is 0.16866715
# Saving image of digit 3
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 4 is 0.16547282
# Saving image of digit 4
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 5 is 0.18394616
# Saving image of digit 5
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 6 is 0.1710428
# Saving image of digit 6
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 7 is 0.14972854
# Saving image of digit 7
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 8 is 0.17329776
# Saving image of digit 8
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 9 is 0.16365245
# Saving image of digit 9
# Final RMSE is 0.16609772
# Accuracy on test images using DP with lambda 0.5 is 0.1105
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 0 is inf
# Saving image of digit 0
# /anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:823: UserWarning: Warning: converting a masked element to nan.
#   dtype = np.min_scalar_type(value)
# /anaconda3/lib/python3.6/site-packages/numpy/ma/core.py:2784: UserWarning: Warning: converting a masked element to nan.
#   order=order, subok=True, ndmin=ndmin)
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 1 is inf
# Saving image of digit 1
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 2 is inf
# Saving image of digit 2
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 3 is inf
# Saving image of digit 3
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 4 is inf
# Saving image of digit 4
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 5 is inf
# Saving image of digit 5
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 6 is inf
# Saving image of digit 6
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 7 is inf
# Saving image of digit 7
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 8 is inf
# Saving image of digit 8
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 9 is inf
# Saving image of digit 9
# Final RMSE is inf
# Accuracy on test images using DP with lambda 1.0 is 0.0838
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 0 is inf
# Saving image of digit 0
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 1 is inf
# Saving image of digit 1
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 2 is inf
# Saving image of digit 2
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 3 is inf
# Saving image of digit 3
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 4 is inf
# Saving image of digit 4
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 5 is inf
# Saving image of digit 5
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 6 is inf
# Saving image of digit 6
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 7 is inf
# Saving image of digit 7
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 8 is inf
# Saving image of digit 8
# Calculating minimum RMSE of image computed against all train samples:
# RMSE of digit 9 is inf
# Saving image of digit 9
# Final RMSE is inf
